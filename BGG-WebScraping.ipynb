# %%
import bs4
from bs4 import BeautifulSoup
import requests
import re
import html
import pandas as pd
import nltk

# %% [markdown]
# # Web Scraping

# %%
def getGameList(genreString, numPages):
    games_list = []
    for i in range(1,numPages+1):
        source = requests.get('https://boardgamegeek.com/'+genreString+'/browse/boardgame/page/' + str(i))
        soup = BeautifulSoup(source.text, 'lxml')
        symbolslist = soup.find('table').tr.next_siblings
        for sec in symbolslist:
            if type(sec) is not bs4.element.NavigableString:
                temp = sec.find('td', class_='collection_thumbnail').a.attrs['href']
                games_list.append(temp)
    return games_list

# %%
source = requests.get('https://boardgamegeek.com/thematic/browse/boardgame/page/1')
soup = BeautifulSoup(source.text, 'lxml')
symbolslist = soup.find('table').tr.next_siblings
for sec in symbolslist:
    if type(sec) is not bs4.element.NavigableString:
        temp = sec.find('td', class_='collection_thumbnail').a.attrs['href']

# %%
thematic_list = getGameList("thematic",50)
print("Thematic:", len(thematic_list))

child_list = getGameList("childrensgames",50)
print("Child:", len(child_list))

fam_list = getGameList("familygames",50)
print("Family:", len(fam_list))

strat_list = getGameList("strategygames",50)
print("Strategy:", len(strat_list))

war_list = getGameList("wargames",50)
print("War:", len(war_list))

abs_list = getGameList("abstracts",50)
print("Abstract:", len(abs_list))
# Out:
# Thematic: 1565
# Child: 4038
# Family: 2608
# Strategy: 2840
# War: 5000
# Abstract: 4669

# %%
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

def getGameDF(gamesList):
    df = pd.DataFrame(columns = ["name",
                   "description", "types", "categories"])
    for el in gamesList:
        newSource = requests.get('https://www.boardgamegeek.com/xmlapi/boardgame/' + el.split('/')[2] + '?stats=1')
        print(el)
        soup = BeautifulSoup(newSource.text, 'html.parser')

        # Game name
        for names in soup.find_all('name'):
            if names.get('primary') == 'true':
                name = names.encode_contents().decode("utf-8")

        # Description
        description = cleanhtml(html.unescape(soup.find('description').encode_contents().decode("utf-8")))

        # Game Types
        types = [domain.encode_contents().decode("utf-8").split(" ")[0] for domain in soup.find_all('boardgamesubdomain')]

        # Game Categories
        categories = [cat.encode_contents().decode("utf-8").split(" ")[0] for cat in soup.find_all('boardgamecategory')]


        df.loc[len(df)] = [name,
                           description,
                           types,
                           categories
                           ]

    return df

# %%
theme_df = getGameDF(thematic_list)
print("Thematic:", len(theme_df))
child_df = getGameDF(child_list)
print("Children's:", len(child_df))
fam_df = getGameDF(fam_list)
print("Family:", len(fam_df))
strat_df = getGameDF(strat_list)
print("Strategy:", len(strat_df))
war_df = getGameDF(war_list)
print("War:", len(war_df))
abs_df = getGameDF(abs_list)
print("Abstract:", len(abs_df))
# Out:
# /boardgame/174430/gloomhaven
# /boardgame/161936/pandemic-legacy-season-1
# /boardgame/291457/gloomhaven-jaws-lion
# /boardgame/233078/twilight-imperium-fourth-edition
# /boardgame/187645/star-wars-rebellion
# /boardgame/115746/war-ring-second-edition
# /boardgame/266507/clank-legacy-acquisitions-incorporated
# /boardgame/167355/nemesis
# /boardgame/192135/too-many-bones
# /boardgame/205637/arkham-horror-card-game
# /boardgame/55690/kingdom-death-monster
# /boardgame/316554/dune-imperium
# /boardgame/221107/pandemic-legacy-season-2
# /boardgame/314040/pandemic-legacy-season-0
# /boardgame/96848/mage-knight-board-game
# /boardgame/205059/mansions-madness-second-edition
# /boardgame/180263/7th-continent
# /boardgame/209010/mechs-vs-minions
# /boardgame/264220/tainted-grail-fall-avalon
# /boardgame/164153/star-wars-imperial-assault
# /boardgame/235802/too-many-bones-undertow
# /boardgame/253344/cthulhu-death-may-die
# /boardgame/121921/robinson-crusoe-adventures-cursed-island
# /boardgame/269385/lord-rings-journeys-middle-earth
# /boardgame/12493/twilight-imperium-third-edition
# /boardgame/241451/aeons-end-legacy
# /boardgame/37111/battlestar-galactica-board-game
# /boardgame/146021/eldritch-horror
# /boardgame/146652/legendary-encounters-alien-deck-building-game
# /boardgame/82222/xia-legends-drift-system
# /boardgame/255984/sleeping-gods
# /boardgame/9609/war-ring
# /boardgame/2511/sherlock-holmes-consulting-detective-thames-murder
# /boardgame/43111/chaos-old-world
# /boardgame/195421/near-and-far
# /boardgame/188920/war-mine-board-game
# /boardgame/223321/detective-modern-crime-board-game
# /boardgame/187617/nemos-war-second-edition
# /boardgame/104162/descent-journeys-dark-second-edition
# /boardgame/302723/forgotten-waters
# /boardgame/282524/horrified
# /boardgame/139976/cthulhu-wars
# /boardgame/239188/chronicles-crime
# /boardgame/283355/dune
# /boardgame/146508/time-stories
# /boardgame/231733/obsession
# /boardgame/150376/dead-winter-crossroads-game
# /boardgame/155068/arcadia-quest
# /boardgame/171131/captain-sonar
# /boardgame/170771/sword-sorcery
# /boardgame/271896/star-wars-outer-rim
# /boardgame/163745/star-wars-armada
# /boardgame/176189/zombicide-black-plague
# /boardgame/15985/blood-bowl-living-rulebook
# /boardgame/169427/middara-unintentional-malum-act-1
# /boardgame/59294/runewars
# /boardgame/232405/western-legends
# /boardgame/203420/exit-game-abandoned-cabin
# /boardgame/39463/cosmic-encounter
# /boardgame/129437/legendary-marvel-deck-building-game
# /boardgame/193037/dead-winter-long-night
# /boardgame/204305/sherlock-holmes-consulting-detective-jack-ripper-w
# /boardgame/175095/dawn-zeds-third-edition
# /boardgame/146791/shadows-brimstone-city-ancients
# /boardgame/97207/dungeon-petz
# /boardgame/257499/arkham-horror-third-edition
# /boardgame/181279/fury-dracula-thirdfourth-edition
# /boardgame/31481/galaxy-trucker
# /boardgame/151347/millennium-blades
# /boardgame/245655/kings-dilemma
# /boardgame/172081/burgle-bros
# /boardgame/38453/space-alert
# /boardgame/212445/blood-bowl-2016-edition
# /boardgame/121/dune
# /boardgame/54625/space-hulk-third-edition
# /boardgame/188866/awkward-guests
# /boardgame/150997/shadows-brimstone-swamps-death
# /boardgame/36932/claustrophobia
# /boardgame/25292/merchants-marauders
# /boardgame/240196/betrayal-legacy
# /boardgame/119506/freedom-underground-railroad
# /boardgame/285192/destinies
# /boardgame/135219/battle-five-armies
# /boardgame/195539/godfather-corleones-empire
# /boardgame/198953/pax-renaissance
# /boardgame/90137/blood-bowl-team-manager-card-game
# /boardgame/172818/above-and-below
# /boardgame/712/blood-bowl-third-edition
# /boardgame/59959/letters-whitechapel
# /boardgame/266121/unlock-heroic-adventures
# /boardgame/73171/earth-reborn
# /boardgame/179803/arcadia-quest-inferno
# /boardgame/160010/conan
# /boardgame/300531/paleo
# /boardgame/181304/mysterium
# /boardgame/156858/black-orchestra
# /boardgame/128671/spartacus-game-blood-and-treachery
# /boardgame/233312/stuffed-fables
# /boardgame/11170/heroscape-master-set-rise-valkyrie
# /boardgame/173064/leaving-earth
# /boardgame/193949/star-trek-ascendancy
# /boardgame/151022/baseball-highlights-2045
# /boardgame/199042/harry-potter-hogwarts-battle
# /boardgame/124708/mice-and-mystics
# /boardgame/138161/firefly-game
# /boardgame/224710/zombicide-green-horde
# /boardgame/42776/gears-war-board-game
# /boardgame/192153/pandemic-reign-cthulhu
# /boardgame/25417/battlelore
# /boardgame/17226/descent-journeys-dark
# /boardgame/181530/runebound-third-edition
# /boardgame/20437/lords-vegas
# /boardgame/83330/mansions-madness
# /boardgame/291572/oath-chronicles-empire-and-exile
# /boardgame/22827/starcraft-board-game
# /boardgame/100901/flash-point-fire-rescue
# /boardgame/279613/unlock-timeless-adventures
# /boardgame/15987/arkham-horror
# /boardgame/79127/star-trek-fleet-captains
# /boardgame/2163/space-hulk
# /boardgame/15363/nexus-ops
# /boardgame/165838/space-hulk-fourth-edition
# /boardgame/256999/project-elite
# /boardgame/171668/grizzled
# /boardgame/156689/legendary-marvel-deck-building-game-villains
# /boardgame/31563/middle-earth-quest
# /boardgame/27976/heroscape-master-set-swarm-marro
# /boardgame/181521/warhammer-quest-adventure-card-game
# /boardgame/65532/defenders-realm
# /boardgame/195137/catacombs-third-edition
# /boardgame/218074/detective-city-angels
# /boardgame/133038/pathfinder-adventure-card-game-rise-runelords-base
# /boardgame/102652/sentinels-multiverse
# /boardgame/127398/legends-andor
# /boardgame/34119/tales-arabian-nights
# /boardgame/155624/specter-ops
# /boardgame/939/star-wars-queens-gambit
# /boardgame/207243/city-kings
# /boardgame/15062/shadows-over-camelot
# /boardgame/257518/claustrophobia-1643
# /boardgame/248065/zombicide-invader
# /boardgame/218421/street-masters
# /boardgame/174570/legendary-encounters-predator-deck-building-game
# /boardgame/137988/zombicide-season-2-prison-outbreak
# /boardgame/117915/yedo
# /boardgame/210296/dinogenics
# /boardgame/195560/wasteland-express-delivery-service
# /boardgame/91312/discworld-ankh-morpork
# /boardgame/300300/chronicles-crime-1400
# /boardgame/203417/exit-game-secret-lab
# /boardgame/242639/treasure-island
# /boardgame/18/roborally
# /boardgame/20963/fury-dracula-second-edition
# /boardgame/108906/thunder-alley
# /boardgame/172047/others
# /boardgame/223953/kitchen-rush
# /boardgame/208024/reckoners
# /boardgame/161866/zombicide-season-3-rue-morgue
# /boardgame/222514/batman-gotham-city-chronicles
# /boardgame/113997/tajemnicze-domostwo
# /boardgame/85897/thunderstone-dragonspire
# /boardgame/91872/dungeons-dragons-legend-drizzt-board-game
# /boardgame/148319/tragedy-looper
# /boardgame/113924/zombicide
# /boardgame/137649/level-7-omega-protocol
# /boardgame/273330/bloodborne-board-game
# /boardgame/170416/vast-crystal-caverns
# /boardgame/37904/formula-d
# /boardgame/73761/k2
# /boardgame/52461/legacy-testament-duke-de-crecy
# /boardgame/151004/smash-science-fiction-double-feature
# /boardgame/131646/merchant-venus-second-edition
# /boardgame/164265/witness
# /boardgame/216092/unlock-escape-adventures-squeek-sausage
# /boardgame/1634/warhammer-quest
# /boardgame/126100/mythos-tales
# /boardgame/163602/xcom-board-game
# /boardgame/272738/jaws
# /boardgame/159504/folklore-affliction
# /boardgame/182694/watson-holmes
# /boardgame/100423/elder-sign
# /boardgame/71721/space-hulk-death-angel-card-game
# /boardgame/66356/dungeons-dragons-wrath-ashardalon-board-game
# /boardgame/179172/unfair
# /boardgame/179275/one-deck-dungeon
# /boardgame/699/heroquest
# /boardgame/234669/legacy-dragonholt
# /boardgame/204472/sub-terra
# /boardgame/202408/adrenaline
# /boardgame/196202/rum-bones-second-tide
# /boardgame/151007/pathfinder-adventure-card-game-skull-shackles-base
# /boardgame/243759/hellboy-board-game
# /boardgame/156091/sons-anarchy-men-mayhem
# /boardgame/239472/abomination-heir-frankenstein
# /boardgame/67492/battles-westeros
# /boardgame/160610/thunderbirds
# /boardgame/104363/rex-final-days-empire
# /boardgame/104710/wiz-war-eighth-edition
# /boardgame/224/history-world
# /boardgame/135382/shadowrun-crossfire
# /boardgame/216459/lost-expedition
# /boardgame/95103/fortune-and-glory-cliffhanger-game
# /boardgame/280794/etherfields
# /boardgame/53953/thunderstone
# /boardgame/138431/galaxy-defenders
# /boardgame/10547/betrayal-house-hill
# /boardgame/219100/uboot-board-game
# /boardgame/197070/massive-darkness
# /boardgame/238992/call-adventure
# /boardgame/281655/high-frontier-4-all
# /boardgame/169124/flick-em
# /boardgame/202077/deep-madness
# /boardgame/183571/deep-space-d-6
# /boardgame/188547/maximum-apocalypse
# /boardgame/183880/risk-star-wars-edition
# /boardgame/71671/yggdrasil
# /boardgame/60435/rallyman
# /boardgame/163474/v-sabotage
# /boardgame/59946/dungeons-dragons-castle-ravenloft-board-game
# /boardgame/98527/gloom-kilforth-fantasy-quest-game
# /boardgame/57390/catacombs
# /boardgame/47055/high-frontier
# /boardgame/141423/dead-men-tell-no-tales
# /boardgame/29368/last-night-earth-zombie-game
# /boardgame/254591/heroes-terrinoth
# /boardgame/256589/rallyman-gt
# /boardgame/216091/unlock-escape-adventures-formula
# /boardgame/172220/dungeons-dragons-temple-elemental-evil-board-game
# /boardgame/125752/race-formula-90
# /boardgame/172737/high-frontier-third-edition
# /boardgame/125678/dc-comics-deck-building-game
# /boardgame/175324/fog-love
# /boardgame/264198/warhammer-quest-blackstone-fortress
# /boardgame/273703/altar-quest
# /boardgame/111124/dark-moon
# /boardgame/3072/necromunda
# /boardgame/171662/neanderthal
# /boardgame/171726/project-elite
# /boardgame/142852/dc-comics-deck-building-game-heroes-unite
# /boardgame/253214/escape-tales-awakening
# /boardgame/221/ikusa
# /boardgame/151771/la-cosa-nostra
# /boardgame/35815/touch-evil-supernatural-game
# /boardgame/21523/runebound-second-edition
# /boardgame/224821/one-deck-dungeon-forest-shadows
# /boardgame/82168/escape-aliens-outer-space
# /boardgame/210232/dungeon-degenerates-hand-doom
# /boardgame/226501/dragonfire
# /boardgame/205317/doom-board-game
# /boardgame/120523/nothing-personal
# /boardgame/221769/biosmegafauna-second-edition
# /boardgame/322708/descent-legends-dark
# /boardgame/211716/john-company
# /boardgame/159109/xenoshyft-onslaught
# /boardgame/281946/aftermath
# /boardgame/228855/set-watch
# /boardgame/1540/battletech
# /boardgame/134253/hostage-negotiator
# /boardgame/187700/gkr-heavy-hitters
# /boardgame/159503/captain-dead
# /boardgame/230303/unlock-mystery-adventures-house-hill
# /boardgame/195571/legendary-encounters-firefly-deck-building-game
# /boardgame/283317/7th-continent-classic-edition
# /boardgame/823/lord-rings
# /boardgame/22/magic-realm
# /boardgame/152765/thunderstone-advance-worlds-collide
# /boardgame/228660/betrayal-baldurs-gate
# /boardgame/169416/pathfinder-adventure-card-game-wrath-righteous-bas
# /boardgame/244536/tiny-epic-zombies
# /boardgame/129459/duel-ages-ii
# /boardgame/122240/last-night-earth-timber-peak
# /boardgame/230305/unlock-mystery-adventures-tonipals-treasure
# /boardgame/3565/mordheim-city-damned
# /boardgame/184824/gaslands-post-apocalyptic-vehicular-combat
# /boardgame/142961/thunderstone-advance-numenera
# /boardgame/122842/exodus-proxima-centauri
# /boardgame/22038/warrior-knights
# /boardgame/232918/fallout
# /boardgame/286751/zombicide-2nd-edition
# /boardgame/148729/maquis
# /boardgame/223376/song-ice-fire-tabletop-miniatures-game-stark-vs-la
# /boardgame/302388/back-future-back-time
# /boardgame/177354/frostgrave
# /boardgame/301767/mysterium-park
# /boardgame/54361/heroscape-master-set-battle-underdark
# /boardgame/180771/teenage-mutant-ninja-turtles-shadows-past
# /boardgame/101785/d-day-dice
# /boardgame/103/titan
# /boardgame/230791/time-legends-joan-arc
# /boardgame/178054/study-emerald-second-edition
# /boardgame/94362/rune-age
# /boardgame/67254/warmachine-prime-mk-ii
# /boardgame/10640/doom-boardgame
# /boardgame/181524/masmorra-dungeons-arcadia
# /boardgame/144568/dawn-zeds-second-edition
# /boardgame/3284/star-wars-epic-duels
# /boardgame/15/cosmic-encounter
# /boardgame/196/kremlin
# /boardgame/215840/exit-game-forbidden-castle
# /boardgame/312267/star-wars-unlock
# /boardgame/248158/thanos-rising-avengers-infinity-war
# /boardgame/63543/horus-heresy
# /boardgame/267813/adventure-games-dungeon
# /boardgame/240271/core-space
# /boardgame/127024/room-25
# /boardgame/227456/escape-dark-castle
# /boardgame/1568/space-crusade
# /boardgame/2251/strat-o-matic-baseball
# /boardgame/209324/world-smog-rise-moloch
# /boardgame/31759/battletech-introductory-box-set
# /boardgame/111105/agents-smersh
# /boardgame/210290/legendary-buffy-vampire-slayer
# /boardgame/207729/edge-dawnfall
# /boardgame/212281/village-attacks
# /boardgame/209660/dungeon-alliance
# /boardgame/142079/space-cadets-dice-duel
# /boardgame/24703/heroscape-marvel-conflict-begins
# /boardgame/212346/shadows-brimstone-forbidden-fortress
# /boardgame/197572/warhammer-quest-silver-tower
# /boardgame/39339/android
# /boardgame/248918/court-dead-mourners-call
# /boardgame/33451/red-dragon-inn-2
# /boardgame/112092/shadowrift
# /boardgame/176083/hit-z-road
# /boardgame/66510/red-dragon-inn-3
# /boardgame/214484/hexplore-it-valley-dead-king
# /boardgame/287938/kitchen-rush-revised-edition
# /boardgame/168788/rum-bones
# /boardgame/150293/ravens-thri-sahashri
# /boardgame/71836/onirim
# /boardgame/187273/dresden-files-cooperative-card-game
# /boardgame/31552/wings-war-deluxe-set
# /boardgame/195856/bloodborne-card-game
# /boardgame/15953/wings-war-burning-drachens
# /boardgame/71906/castaways
# /boardgame/98918/biosgenesis
# /boardgame/9910/wings-war-watch-your-back
# /boardgame/216070/hunt-ring
# /boardgame/89910/run-fight-or-die
# /boardgame/118536/police-precinct
# /boardgame/22192/heroquest-advanced-quest
# /boardgame/384/turfmaster
# /boardgame/204286/big-trouble-little-china-game
# /boardgame/144826/zombie-15
# /boardgame/71882/conquest-planet-earth-space-alien-game
# /boardgame/225167/human-punishment-social-deduction-20
# /boardgame/231327/grizzled-armistice-edition
# /boardgame/124827/space-cadets-away-missions
# /boardgame/254192/harry-potter-hogwarts-battle-defence-against-dark
# /boardgame/40529/cosmic-encounter
# /boardgame/43868/adventurers-temple-chac
# /boardgame/232361/after-virus
# /boardgame/242/junta
# /boardgame/157958/dungeonquest-revised-edition
# /boardgame/220827/planet-apocalypse
# /boardgame/17223/world-warcraft-boardgame
# /boardgame/128442/relic
# /boardgame/155463/dc-comics-deck-building-game-forever-evil
# /boardgame/4741/warmachine
# /boardgame/98315/adventurers-pyramid-horus
# /boardgame/220632/monster-slaughter
# /boardgame/197097/four-against-darkness
# /boardgame/218311/deckscape-test-time
# /boardgame/92044/dungeons-dragons-conquest-nerath-board-game
# /boardgame/216094/unlock-escape-adventures-island-doctor-goorse
# /boardgame/156501/greenland
# /boardgame/17710/conquest-empire
# /boardgame/12477/bootleggers
# /boardgame/128445/darkest-night
# /boardgame/123096/space-cadets
# /boardgame/472/dungeonquest
# /boardgame/120217/city-horror
# /boardgame/233868/hate
# /boardgame/276925/warhammer-age-sigmar-warcry-starter-set
# /boardgame/76150/revolver
# /boardgame/166286/bottom-9th
# /boardgame/154509/kingsport-festival
# /boardgame/193670/darkest-night-second-edition
# /boardgame/1044/gunslinger
# /boardgame/16772/mall-horror
# /boardgame/3720/subbuteo
# /boardgame/226634/thing-infection-outpost-31
# /boardgame/137031/ancient-terrible-things
# /boardgame/28259/cutthroat-caverns
# /boardgame/71061/dungeonquest-third-edition
# /boardgame/589/wiz-war
# /boardgame/9341/lost-valley
# /boardgame/248949/skull-tales-full-sail
# /boardgame/245045/deckscape-heist-venice
# /boardgame/160081/dungeon-saga-dwarf-kings-quest
# /boardgame/284775/funkoverse-strategy-game
# /boardgame/99/fortress-america
# /boardgame/198707/hostage-negotiator-crime-wave
# /boardgame/274428/gaslands-refuelled
# /boardgame/270239/moonrakers
# /boardgame/12350/battlestations
# /boardgame/102237/drako-dragon-dwarves
# /boardgame/27848/age-conan-strategy-board-game
# /boardgame/118063/android-infiltration
# /boardgame/149241/assault-doomrock
# /boardgame/190400/aventuria-adventure-card-game
# /boardgame/936/fury-dracula
# /boardgame/171479/commissioned
# /boardgame/256852/aliens-another-glorious-day-corps
# /boardgame/119781/legacy-gears-time
# /boardgame/199723/ultraquest-gold-ruhm-und-ehre
# /boardgame/140343/carnival-zombie
# /boardgame/63091/space-hulk-second-edition
# /boardgame/191301/walking-dead-all-out-war
# /boardgame/24310/red-dragon-inn
# /boardgame/200454/planetarium
# /boardgame/2288/blood-bowl-second-edition
# /boardgame/42939/invasion-outer-space-martian-game
# /boardgame/99392/colonial-europes-empires-overseas
# /boardgame/788/tales-arabian-nights
# /boardgame/245353/unlock-secret-adventures-tombstone-express
# /boardgame/219217/arena-contest
# /boardgame/159469/ortus-regni
# /boardgame/133528/city-remnants
# /boardgame/274450/last-aurora
# /boardgame/147537/malifaux-second-edition
# /boardgame/2516/man-o-war
# /boardgame/154301/battle-kembles-cascade
# /boardgame/127127/lord-rings-fellowship-ring-deck-building-game
# /boardgame/1621/mutant-chronicles-siege-citadel
# /boardgame/168054/grifters
# /boardgame/244/circus-maximus
# /boardgame/232666/robin-hood-and-merry-men
# /boardgame/8095/prophecy
# /boardgame/715/escape-colditz
# /boardgame/235591/history-world
# /boardgame/80771/dungeon-raiders
# /boardgame/136000/rivet-wars-eastern-front
# /boardgame/160958/dc-comics-deck-building-game-rivals-batman-vs-joke
# /boardgame/154910/darklight-memento-mori
# /boardgame/153097/heroes-wanted
# /boardgame/303051/godzilla-tokyo-clash
# /boardgame/38506/witch-salem
# /boardgame/181495/alone
# /boardgame/186721/healthy-heart-hospital
# /boardgame/156548/super-dungeon-explore-forgotten-king
# /boardgame/140125/fallen
# /boardgame/1770/aliens
# /boardgame/230769/who-goes-there
# /boardgame/147930/king-assassins
# /boardgame/124668/dwarves
# /boardgame/23604/world-cup-game
# /boardgame/83040/leader-1-hell-north
# /boardgame/16366/funny-friends
# /boardgame/27627/talisman-revised-4th-edition
# /boardgame/168274/mistfall
# /boardgame/108722/dreadfleet
# /boardgame/1234/once-upon-time-storytelling-card-game
# /boardgame/225729/arkham-noir-case-1-witch-cult-murders
# /boardgame/3967/battlefleet-gothic
# /boardgame/143096/camp-grizzly
# /boardgame/231197/raxxon
# /boardgame/247417/solomon-kane
# /boardgame/140951/thunderstone-starter-set
# /boardgame/164702/glorantha-gods-war
# /boardgame/96792/road-canterbury
# /boardgame/805/buffy-vampire-slayer-game
# /boardgame/27463/galactic-emperor
# /boardgame/97915/bios-megafauna
# /boardgame/267814/adventure-games-monochrome-inc
# /boardgame/4491/cave-troll
# /boardgame/245928/pax-emancipation
# /boardgame/156266/apex-theropod-deck-building-game
# /boardgame/253106/narcos-board-game
# /boardgame/28/illuminati
# /boardgame/162/awful-green-things-outer-space
# /boardgame/19854/federation-commander-klingon-border
# /boardgame/192455/first-martians-adventures-red-planet
# /boardgame/84889/cave-evil
# /boardgame/209671/zona-secret-chernobyl
# /boardgame/8170/return-heroes
# /boardgame/18985/battleground
# /boardgame/25261/tannhauser
# /boardgame/169704/vault-wars
# /boardgame/6050/duel-ages-set-1-worldspanner
# /boardgame/280748/escape-dark-sector
# /boardgame/230342/inbetween
# /boardgame/247585/waste-knights-second-edition
# /boardgame/95105/1st-goal
# /boardgame/264476/rangers-shadow-deep
# /boardgame/19679/hordes
# /boardgame/226631/war-worlds-new-wave
# /boardgame/250561/kick-ass-board-game
# /boardgame/78954/mousquetaires-du-roy
# /boardgame/216381/hand-fate-ordeals
# /boardgame/177079/die-legenden-von-andor-chada-thorn
# /boardgame/1758/advanced-heroquest
# /boardgame/261393/dungeon-universalis
# /boardgame/22551/risk-star-wars-original-trilogy-edition
# /boardgame/52328/malifaux
# /boardgame/237031/d100-dungeon
# /boardgame/132428/bioshock-infinite-siege-columbia
# /boardgame/129351/cave
# /boardgame/149787/perditions-mouth-abyssal-rift
# /boardgame/238916/shadows-kilforth-fantasy-quest-game
# /boardgame/253719/getaway-driver
# /boardgame/316412/loop
# /boardgame/58/kings-things
# /boardgame/293531/detective-modern-crime-board-game-season-one
# /boardgame/93538/battleship-galaxies
# /boardgame/251420/choose-your-own-adventure-house-danger
# /boardgame/173805/lobotomy
# /boardgame/284333/yggdrasil-chronicles
# /boardgame/231991/firefly-adventures-brigands-and-browncoats
# /boardgame/12692/gloom
# /boardgame/172552/karmaka
# /boardgame/160968/homeland-game
# /boardgame/37165/warhammer-40000-fifth-edition
# /boardgame/124380/ladies-gentlemen
# /boardgame/251723/zombicide-dark-side
# /boardgame/14808/marvel-heroes
# /boardgame/255907/trogdor-board-game
# /boardgame/79131/star-trek-expeditions
# /boardgame/178134/london-dread
# /boardgame/124847/1911-amundsen-vs-scott
# /boardgame/179820/tail-feathers
# /boardgame/131891/lost-legends
# /boardgame/4985/warmaster
# /boardgame/140519/myth
# /boardgame/178613/star-trek-five-year-mission
# /boardgame/8107/risk-lord-rings-trilogy-edition
# /boardgame/30/dark-tower
# /boardgame/3893/full-thrust
# /boardgame/204605/unicornus-knights
# /boardgame/262733/reichbusters-projekt-vril
# /boardgame/207910/subatomic-atom-building-game
# /boardgame/150484/secrets-lost-tomb
# /boardgame/102148/noir-deductive-mystery-game
# /boardgame/2795/car-wars
# /boardgame/17804/dungeons-dragons-basic-game
# /boardgame/6366/dungeons-dragons-fantasy-adventure-board-game
# /boardgame/206206/escape-100-million-bc
# /boardgame/145601/deadline
# /boardgame/2470/extraordinary-adventures-baron-munchausen
# /boardgame/29109/dust
# /boardgame/714/talisman
# /boardgame/245197/deadwood-1876
# /boardgame/64826/moongha-invaders-mad-scientists-and-atomic-monster
# /boardgame/197831/dark-souls-board-game
# /boardgame/257674/vampire-masquerade-heritage
# /boardgame/1213/nuclear-escalation
# /boardgame/804/thunder-road
# /boardgame/142555/lord-rings-two-towers-deck-building-game
# /boardgame/171835/posthuman
# /boardgame/98347/empires-void
# /boardgame/146408/sentinel-tactics-flame-freedom
# /boardgame/125943/corporate-america
# /boardgame/302193/wonder-woman-challenge-amazons
# /boardgame/231553/jagged-alliance-board-game
# /boardgame/230498/deckscape-fate-london
# /boardgame/226176/fallout-wasteland-warfare
# /boardgame/23/divine-right
# /boardgame/29602/okko-era-asagiri
# /boardgame/148261/seafall
# /boardgame/20079/pacific-typhoon
# /boardgame/3548/assault-hoth-empire-strikes-back
# /boardgame/252693/batman-animated-series-gotham-city-under-siege
# /boardgame/9825/early-american-chrononauts
# /boardgame/154510/shadows-malice
# /boardgame/144743/machina-arcana
# /boardgame/95234/cthulhu-gloom
# /boardgame/98242/star-trek-deck-building-game-next-generation
# /boardgame/113293/article-27-un-security-council-game
# /boardgame/171964/order-vampire-hunters
# /boardgame/72809/barbarossa
# /boardgame/198832/legends-untold-weeping-caves-novice-set
# /boardgame/40531/cosmic-encounter
# /boardgame/26055/twilight-imperium-second-edition
# /boardgame/123160/battle-souls
# /boardgame/175973/hunters-d-2114
# /boardgame/147747/super-fantasy-ugly-snouts-assault
# /boardgame/29581/tomb
# /boardgame/148205/penny-press
# /boardgame/160964/star-wars-empire-vs-rebellion
# /boardgame/167698/magic-gathering-arena-planeswalkers
# /boardgame/171630/drakon-fourth-edition
# /boardgame/253574/crusader-kings
# /boardgame/110524/goblins-inc
# /boardgame/75223/utopia-engine
# /boardgame/6795/battleball
# /boardgame/84159/junta-viva-el-presidente
# /boardgame/181523/snowblind-race-pole
# /boardgame/96613/alcatraz-scapegoat
# /boardgame/261403/inhuman-conditions
# /boardgame/192927/last-friday
# /boardgame/147116/witcher-adventure-game
# /boardgame/5534/light-speed
# /boardgame/298102/roll-camera-filmmaking-board-game
# /boardgame/40603/incursion
# /boardgame/152510/lord-rings-return-king-deck-building-game
# /boardgame/29805/petits-meurtres-faits-divers
# /boardgame/226588/untold-adventures-await
# /boardgame/8515/hybrid
# /boardgame/3463/wizard
# /boardgame/65225/road-kill-rally
# /boardgame/169141/fallen-land-post-apocalyptic-board-game
# /boardgame/1212/nuclear-proliferation
# /boardgame/2535/valley-mammoths
# /boardgame/13751/under-shadow-dragon
# /boardgame/28805/lord-rings-strategy-battle-game
# /boardgame/164865/b-sieged-sons-abyss
# /boardgame/122690/star-trek-deck-building-game-original-series
# /boardgame/61484/zombie-state-diplomacy-dead
# /boardgame/111502/star-trek-deck-building-game-next-generation-next
# /boardgame/815/chrononauts
# /boardgame/1717/freedom-galaxy-star-rebellions-5764-ad
# /boardgame/145642/cards-cthulhu
# /boardgame/2363/orient-express
# /boardgame/69120/cadwallon-city-thieves
# /boardgame/8207/dungeoneer-vault-fiends
# /boardgame/147623/frieses-landlord
# /boardgame/42142/doctor-who-solitaire-story-game
# /boardgame/21373/federation-commander-romulan-border
# /boardgame/24/twilight-imperium
# /boardgame/244274/crusoe-crew
# /boardgame/66424/dungeon-run
# /boardgame/225885/unbroken
# /boardgame/235/blackbeard
# /boardgame/5316/warhammer-epic-40000
# /boardgame/713/nuclear-war
# /boardgame/55863/three-musketeers-queens-pendants
# /boardgame/145308/marrying-mr-darcy
# /boardgame/224894/michael-strogoff
# /boardgame/5336/talisman-third-edition
# /boardgame/392/brawl
# /boardgame/175334/undercity-iron-kingdoms-adventure-board-game
# /boardgame/7571/winds-plunder
# /boardgame/154905/brew-crafters-travel-card-game
# /boardgame/1143/warrior-knights
# /boardgame/138166/huida-de-silver-city
# /boardgame/5576/dungeoneer-tomb-lich-lord
# /boardgame/161880/quiet-year
# /boardgame/157088/essen-game-spiel13
# /boardgame/39232/nemos-war
# /boardgame/21358/savage-worlds
# /boardgame/189222/saltlands
# /boardgame/859/illuminati
# /boardgame/149896/alien-vs-predator-hunt-begins
# /boardgame/5740/strat-o-matic-pro-football
# /boardgame/3086/omega-virus
# /boardgame/17851/pizza-box-football
# /boardgame/10383/risk-godstorm
# /boardgame/3730/statis-pro-baseball
# /boardgame/1577/source-nile
# /boardgame/166776/skull-tales
# /boardgame/248/blood-royale
# /boardgame/155025/magnates-game-power
# /boardgame/217894/delve
# /boardgame/209696/star-saga
# /boardgame/171356/argonauts
# /boardgame/101013/ninja-legend-scorpion-clan
# /boardgame/43320/tomb-cryptmaster
# /boardgame/173275/ghostbusters-board-game
# /boardgame/149097/spurs-tale-old-west
# /boardgame/46782/rush-n-crush
# /boardgame/230191/island-el-dorado
# /boardgame/163937/world-yo-ho
# /boardgame/135877/fish-cook
# /boardgame/140795/say-bye-villains
# /boardgame/1498/paydirt
# /boardgame/108344/might-magic-heroes
# /boardgame/69851/aliens-time-its-war
# /boardgame/179719/risk-game-thrones
# /boardgame/62853/jab-realtime-boxing
# /boardgame/29294/world-warcraft-adventure-game
# /boardgame/279307/1942-uss-yorktown
# /boardgame/25071/munchkin-cthulhu
# /boardgame/33468/zombie-my-pocket
# /boardgame/3095/star-trek-adventure-game
# /boardgame/6923/battletech-citytech
# /boardgame/7479/warcraft-board-game
# /boardgame/257305/shasn
# /boardgame/86955/munchkin-zombies
# /boardgame/34/arkham-horror
# /boardgame/5369/hordes-things
# /boardgame/286827/decktective-bloody-red-roses
# /boardgame/3597/strat-o-matic-hockey
# /boardgame/275589/pocket-detective
# /boardgame/141067/history-maker-baseball
# /boardgame/159406/portal-uncooperative-cake-acquisition-game
# /boardgame/35423/founding-fathers
# /boardgame/250481/meltwater-game-tactical-starvation
# /boardgame/9829/runebound
# /boardgame/310/wizards-quest
# /boardgame/255664/binding-isaac-four-souls
# /boardgame/1421/lost-worlds
# /boardgame/175254/apocrypha-adventure-card-game-box-one-world
# /boardgame/72132/dragon-rampage
# /boardgame/28739/garibaldi-escape
# /boardgame/31920/munchkin-booty
# /boardgame/7290/dynasty-league-baseball
# /boardgame/6209/magblast-second-edition
# /boardgame/155065/lifeform
# /boardgame/129976/game-thrones-card-game
# /boardgame/170/family-business
# /boardgame/10167/zombies-4-end
# /boardgame/4095/star-munchkin
# /boardgame/194/groo-game
# /boardgame/97/conquest-empire
# /boardgame/59429/dark-darker-darkest
# /boardgame/13071/age-gods
# /boardgame/230304/unlock-mystery-adventures-nautilus-traps
# /boardgame/75333/target-earth
# /boardgame/256883/comanauts
# /boardgame/57141/codeword-cromwell-german-invasion-england-8-june-1
# /boardgame/168770/epic-pvp-fantasy
# /boardgame/330/block-mania
# /boardgame/222145/lucidity-six-sided-nightmares
# /boardgame/163399/infinity-operation-icestorm
# /boardgame/100169/hero-weehawken
# /boardgame/182260/agent-decker
# /boardgame/257321/gen7-crossroads-game
# /boardgame/173486/dune-dice-game
# /boardgame/69552/panic-station
# /boardgame/176817/assassinorum-execution-force
# /boardgame/1152/mystic-wood
# /boardgame/39941/legion-honor
# /boardgame/299255/vienna-connection
# /boardgame/30166/good-bad-and-munchkin
# /boardgame/34639/dungeon-d
# /boardgame/2063/great-khan-game
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b9efa0ed78e8> in <module>
# ----> 1 theme_df = getGameDF(thematic_list)
#       2 print("Thematic:", len(theme_df))
#       3 child_df = getGameDF(child_list)
#       4 print("Children's:", len(child_df))
#       5 fam_df = getGameDF(fam_list)
#
# <ipython-input-5-3c5921989033> in getGameDF(gamesList)
#       8                    "description", "types", "categories"])
#       9     for el in gamesList:
# ---> 10         newSource = requests.get('https://www.boardgamegeek.com/xmlapi/boardgame/' + el.split('/')[2] + '?stats=1')
#      11         print(el)
#      12         soup = BeautifulSoup(newSource.text, 'html.parser')
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.concat([theme_df,child_df,fam_df,strat_df,war_df,abs_df])
df = df.drop_duplicates(subset=['name'])
df.reset_index(drop=True, inplace=True)
df

# %%
pd.to_pickle(df, 'BGGDataGenre.pkl')

# %%
df = pd.read_pickle('BGGDataGenre.pkl')

# %%
all_genres = sum(df['types'],[])
len(set(all_genres))
print(set(all_genres))
# Out:
# {"Children's", 'Wargames', 'Customizable', 'Thematic', 'Strategy', 'Abstract', 'Party', 'Family'}

# %%
all_genres = nltk.FreqDist(all_genres)

# create dataframe
all_genres_df = pd.DataFrame({'Genre': list(all_genres.keys()),
                              'Count': list(all_genres.values())})

# %%
def clean_df(dataframe):
    approvedGenres = ['Abstract',"Children's",'Family','Strategy','Thematic','Wargames']
    i = 0
    while i < len(dataframe) - 1:
        i += 1
        for genre in dataframe.iloc[i]['types']:
            if genre not in approvedGenres:
                #name = dataframe.iloc[i]['name']
                dataframe = dataframe.drop(i,axis=0)
                dataframe.reset_index(drop=True, inplace=True)
                i -= 1
                #print(i, len(dataframe), name)
    return dataframe

# %%
df = clean_df(df)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                     name  \
# 0                             Gloomhaven
# 1              Pandemic Legacy: Season 1
# 2           Gloomhaven: Jaws of the Lion
# 3      Twilight Imperium: Fourth Edition
# 4                   Star Wars: Rebellion
# ...                                  ...
# 18358                      Knights Poker
# 18359                            Gekitai
# 18360                           Gekitai²
# 18361                     Digit Draughts
# 18362                          Limelight
#
#                                              description  \
# 0      Gloomhaven  is a game of Euro-inspired tactica...
# 1      Pandemic Legacy is a co-operative campaign gam...
# 2      Gloomhaven: Jaws of the Lion is a standalone g...
# 3      Twilight Imperium (Fourth Edition) is a game o...
# 4      Star Wars: Rebellion is a board game of epic c...
# ...                                                  ...
# 18358  Knights Poker is the new board game from the w...
# 18359  Gekitai (Repel or Push Away) is a 3-in-a-row g...
# 18360  Gekitai  (Repel or Push Away) is a 3-in-a-row ...
# 18361  Digit Draughts is a set of three related games...
# 18362  Limelight is played on a 4x4 grid with the cor...
#
#                       types                                         categories
# 0      [Strategy, Thematic]  [Adventure, Exploration, Fantasy, Fighting, Mi...
# 1      [Strategy, Thematic]                           [Environmental, Medical]
# 2      [Strategy, Thematic]  [Adventure, Exploration, Fantasy, Fighting, Mi...
# 3      [Strategy, Thematic]  [Civilization, Economic, Exploration, Negotiat...
# 4                [Thematic]  [Civil, Fighting, Miniatures, Movies, Science,...
# ...                     ...                                                ...
# 18358            [Abstract]                                         [Abstract]
# 18359            [Abstract]                                  [Abstract, Print]
# 18360            [Abstract]                                  [Abstract, Print]
# 18361            [Abstract]                                 [Abstract, Number]
# 18362            [Abstract]                                         [Abstract]
#
# [18363 rows x 4 columns]

# %%
def clean_desc(raw_html):
    clean = re.sub("[^a-zA-Z]"," ",raw_html)
    clean = ' '.join(clean.split())
    clean = clean.lower()
    return clean

# %%
df['description'] = df['description'].apply(lambda x: clean_desc(x))
df
# Out:
#                                     name  \
# 0                             Gloomhaven
# 1              Pandemic Legacy: Season 1
# 2           Gloomhaven: Jaws of the Lion
# 3      Twilight Imperium: Fourth Edition
# 4                   Star Wars: Rebellion
# ...                                  ...
# 18358                      Knights Poker
# 18359                            Gekitai
# 18360                           Gekitai²
# 18361                     Digit Draughts
# 18362                          Limelight
#
#                                              description  \
# 0      gloomhaven is a game of euro inspired tactical...
# 1      pandemic legacy is a co operative campaign gam...
# 2      gloomhaven jaws of the lion is a standalone ga...
# 3      twilight imperium fourth edition is a game of ...
# 4      star wars rebellion is a board game of epic co...
# ...                                                  ...
# 18358  knights poker is the new board game from the w...
# 18359  gekitai repel or push away is a in a row game ...
# 18360  gekitai repel or push away is a in a row game ...
# 18361  digit draughts is a set of three related games...
# 18362  limelight is played on a x grid with the corne...
#
#                       types                                         categories
# 0      [Strategy, Thematic]  [Adventure, Exploration, Fantasy, Fighting, Mi...
# 1      [Strategy, Thematic]                           [Environmental, Medical]
# 2      [Strategy, Thematic]  [Adventure, Exploration, Fantasy, Fighting, Mi...
# 3      [Strategy, Thematic]  [Civilization, Economic, Exploration, Negotiat...
# 4                [Thematic]  [Civil, Fighting, Miniatures, Movies, Science,...
# ...                     ...                                                ...
# 18358            [Abstract]                                         [Abstract]
# 18359            [Abstract]                                  [Abstract, Print]
# 18360            [Abstract]                                  [Abstract, Print]
# 18361            [Abstract]                                 [Abstract, Number]
# 18362            [Abstract]                                         [Abstract]
#
# [18363 rows x 4 columns]
